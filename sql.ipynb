-- %% [markdown]
-- # [poscoffe]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [poscoffe]    Script Date: 7/6/2023 10:07:56 AM ******/
CREATE DATABASE [poscoffe]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'POSCoffee', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\poscoffe.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 1024KB )
 LOG ON 
( NAME = N'POSCoffee_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\poscoffe_0.ldf' , SIZE = 7616KB , MAXSIZE = 2048GB , FILEGROWTH = 10%)
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [poscoffe] SET COMPATIBILITY_LEVEL = 100
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [poscoffe].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [poscoffe] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [poscoffe] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [poscoffe] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [poscoffe] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [poscoffe] SET ARITHABORT OFF 
GO
ALTER DATABASE [poscoffe] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [poscoffe] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [poscoffe] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [poscoffe] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [poscoffe] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [poscoffe] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [poscoffe] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [poscoffe] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [poscoffe] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [poscoffe] SET  DISABLE_BROKER 
GO
ALTER DATABASE [poscoffe] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [poscoffe] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [poscoffe] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [poscoffe] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [poscoffe] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [poscoffe] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [poscoffe] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [poscoffe] SET RECOVERY FULL 
GO
ALTER DATABASE [poscoffe] SET  MULTI_USER 
GO
ALTER DATABASE [poscoffe] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [poscoffe] SET DB_CHAINING OFF 
GO
ALTER DATABASE [poscoffe] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [poscoffe] SET TARGET_RECOVERY_TIME = 0 SECONDS 
GO
ALTER DATABASE [poscoffe] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [poscoffe] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'poscoffe', N'ON'
GO
ALTER DATABASE [poscoffe] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [vanchhai]

-- %%
USE [poscoffe]
GO

-- %%
/****** Object:  User [vanchhai]    Script Date: 7/6/2023 10:07:56 AM ******/
CREATE USER [vanchhai] WITHOUT LOGIN WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [CHHAISERVER]

-- %%
/****** Object:  User [CHHAISERVER]    Script Date: 7/6/2023 10:07:56 AM ******/
CREATE USER [CHHAISERVER] WITHOUT LOGIN WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [chhai]

-- %%
/****** Object:  User [chhai]    Script Date: 7/6/2023 10:07:56 AM ******/
CREATE USER [chhai] WITHOUT LOGIN WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [CHHAISERVER]

-- %%
ALTER ROLE [db_owner] ADD MEMBER [CHHAISERVER]
GO
ALTER ROLE [db_accessadmin] ADD MEMBER [CHHAISERVER]
GO
ALTER ROLE [db_securityadmin] ADD MEMBER [CHHAISERVER]
GO
ALTER ROLE [db_ddladmin] ADD MEMBER [CHHAISERVER]
GO
ALTER ROLE [db_backupoperator] ADD MEMBER [CHHAISERVER]
GO
ALTER ROLE [db_datareader] ADD MEMBER [CHHAISERVER]
GO
ALTER ROLE [db_datawriter] ADD MEMBER [CHHAISERVER]
GO
ALTER ROLE [db_denydatareader] ADD MEMBER [CHHAISERVER]
GO
ALTER ROLE [db_denydatawriter] ADD MEMBER [CHHAISERVER]
GO

-- %% [markdown]
-- # [dbo].[fn_getDigitID]

-- %%
/****** Object:  UserDefinedFunction [dbo].[fn_getDigitID]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE function [dbo].[fn_getDigitID](@number int,@digit int) returns varchar(50)
as 
begin 
	return (REPLICATE('0',@digit-len(CONVERT(varchar(6),@number)))+Convert(varchar(6),@number))
end 

GO

-- %% [markdown]
-- # [dbo].[fn_sum_expens]

-- %%
/****** Object:  UserDefinedFunction [dbo].[fn_sum_expens]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE FUNCTION [dbo].[fn_sum_expens](@datefrom DATE,@dateto DATE) RETURNS DECIMAL(20,2)
AS
BEGIN
	RETURN (SELECT SUM(amount) FROM dbo.tbexpens WHERE ex_date BETWEEN @datefrom AND @dateto)  
END

GO

-- %% [markdown]
-- # [dbo].[fn_sum_sell]

-- %%
/****** Object:  UserDefinedFunction [dbo].[fn_sum_sell]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE FUNCTION [dbo].[fn_sum_sell](@datefrom DATE,@dateto DATE) RETURNS DECIMAL(20,2)
AS
BEGIN
	RETURN (SELECT SUM(payment) FROM dbo.tblInv WHERE InvDate BETWEEN @datefrom AND @dateto)  
END


GO

-- %% [markdown]
-- # [dbo].[tblCat]

-- %%
/****** Object:  Table [dbo].[tblCat]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblCat](
	[CatID] [varchar](255) NOT NULL,
	[CatName] [nvarchar](255) NULL,
	[Image] [nvarchar](255) NULL,
	[description] [nvarchar](max) NULL,
	[createdate] [date] NULL,
	[createby] [nvarchar](50) NULL,
	[updatedate] [date] NULL,
	[updateby] [date] NULL,
	[lock] [int] NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[v_cate]

-- %%
/****** Object:  View [dbo].[v_cate]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE VIEW [dbo].[v_cate]
AS
SELECT 
	CatID AS 'លេខកូត'
	
 FROM dbo.tblCat


GO

-- %% [markdown]
-- # [dbo].[tblProduct]

-- %%
/****** Object:  Table [dbo].[tblProduct]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblProduct](
	[ProID] [varchar](50) NOT NULL,
	[ProName] [nvarchar](255) NULL,
	[Price] [float] NULL,
	[Photo] [varbinary](max) NULL,
	[CatID] [nvarchar](255) NULL,
	[note] [nvarchar](max) NULL,
	[createddate] [date] NULL,
	[createby] [nvarchar](50) NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblProductDetail]

-- %%
/****** Object:  Table [dbo].[tblProductDetail]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblProductDetail](
	[proid] [varchar](100) NULL,
	[type] [nvarchar](50) NULL,
	[price] [decimal](18, 2) NULL,
	[discount] [decimal](18, 2) NULL,
	[islocked] [tinyint] NULL,
	[total] [decimal](18, 2) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[v_product]

-- %%
/****** Object:  View [dbo].[v_product]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE VIEW [dbo].[v_product]
AS
SELECT p.ProID ,
       p.ProName ,
       p.Photo ,
       p.CatID ,
	   c.CatName,
       p.note ,
       d.type ,
       d.price 
FROM dbo.tblProduct p INNER JOIN dbo.tblProductDetail d
ON p.ProID=d.proid INNER JOIN dbo.tblCat c
ON p.CatID=c.CatID

GO

-- %% [markdown]
-- # [dbo].[tbexpens]

-- %%
/****** Object:  Table [dbo].[tbexpens]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbexpens](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[ex_date] [date] NULL,
	[amount] [decimal](20, 2) NULL,
	[descriptions] [nvarchar](max) NULL,
	[createdby] [nvarchar](100) NULL,
	[createdate] [date] NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblExchange]

-- %%
/****** Object:  Table [dbo].[tblExchange]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblExchange](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[rate] [decimal](18, 2) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblInv]

-- %%
/****** Object:  Table [dbo].[tblInv]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblInv](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[InvID] [varchar](100) NOT NULL,
	[InvDate] [date] NULL,
	[InvTime] [time](7) NULL,
	[Amount] [decimal](18, 2) NULL,
	[discount] [decimal](18, 2) NULL,
	[payment] [decimal](18, 2) NULL,
	[createdate] [date] NULL,
	[UserID] [nvarchar](50) NULL,
	[waiting] [nvarchar](50) NULL,
 CONSTRAINT [PK_tblInv] PRIMARY KEY CLUSTERED 
(
	[InvID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblInv_Detail]

-- %%
/****** Object:  Table [dbo].[tblInv_Detail]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblInv_Detail](
	[InvID] [varchar](100) NULL,
	[ProID] [varchar](100) NULL,
	[ProName] [nvarchar](255) NULL,
	[size] [varchar](50) NULL,
	[Qty] [int] NULL,
	[Price] [decimal](18, 2) NULL,
	[discount] [decimal](18, 2) NULL,
	[Total] [decimal](18, 2) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblreport]

-- %%
/****** Object:  Table [dbo].[tblreport]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblreport](
	[ProID] [nvarchar](50) NULL,
	[ProName] [nvarchar](255) NULL,
	[Qty] [int] NULL,
	[Total] [int] NULL,
	[Inv_Date] [date] NULL,
	[UserID] [nvarchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbltest]

-- %%
/****** Object:  Table [dbo].[tbltest]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbltest](
	[photo] [varbinary](max) NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblType]

-- %%
/****** Object:  Table [dbo].[tblType]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblType](
	[typeid] [varchar](50) NULL,
	[type] [nvarchar](50) NULL,
	[islocked] [tinyint] NULL,
	[created_date] [date] NULL,
	[created_by] [nvarchar](50) NULL,
	[update_date] [date] NULL,
	[update_by] [nvarchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblUser]

-- %%
/****** Object:  Table [dbo].[tblUser]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblUser](
	[UserID] [nvarchar](50) NOT NULL,
	[Name] [nvarchar](255) NULL,
	[UserName] [nvarchar](255) NULL,
	[Password] [nvarchar](255) NULL,
	[Phone] [nvarchar](255) NULL,
	[Photo] [nvarchar](255) NULL,
	[position] [nvarchar](50) NULL,
	[Status] [nvarchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbprint]

-- %%
/****** Object:  Table [dbo].[tbprint]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbprint](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[num] [varchar](100) NULL,
	[createdate] [date] NULL,
	[createby] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbwifi]

-- %%
/****** Object:  Table [dbo].[tbwifi]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbwifi](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[pass] [varchar](100) NULL,
	[createdate] [date] NULL,
	[createby] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbexpens]

-- %%
SET IDENTITY_INSERT [dbo].[tbexpens] ON 
INSERT [dbo].[tbexpens] ([id], [ex_date], [amount], [descriptions], [createdby], [createdate]) VALUES (1, CAST(N'2023-06-23' AS Date), CAST(1000.00 AS Decimal(20, 2)), N'1000', N'0002', CAST(N'2023-06-23' AS Date))
SET IDENTITY_INSERT [dbo].[tbexpens] OFF
GO

-- %% [markdown]
-- # [dbo].[tblCat]

-- %%
INSERT [dbo].[tblCat] ([CatID], [CatName], [Image], [description], [createdate], [createby], [updatedate], [updateby], [lock]) VALUES (N'0001', N'Phone', NULL, N'i phone', CAST(N'2023-06-23' AS Date), N'1', NULL, NULL, NULL)
INSERT [dbo].[tblCat] ([CatID], [CatName], [Image], [description], [createdate], [createby], [updatedate], [updateby], [lock]) VALUES (N'0002', N'Coffe', NULL, N'coffe', CAST(N'2023-06-23' AS Date), N'1', NULL, NULL, NULL)
INSERT [dbo].[tblCat] ([CatID], [CatName], [Image], [description], [createdate], [createby], [updatedate], [updateby], [lock]) VALUES (N'0003', N'Milk', NULL, N'Mik', CAST(N'2023-06-23' AS Date), N'1', NULL, NULL, NULL)
INSERT [dbo].[tblCat] ([CatID], [CatName], [Image], [description], [createdate], [createby], [updatedate], [updateby], [lock]) VALUES (N'0004', N'Bike', NULL, N'Bike', CAST(N'2023-06-23' AS Date), N'1', NULL, NULL, NULL)
GO

-- %% [markdown]
-- # [dbo].[tblExchange]

-- %%
SET IDENTITY_INSERT [dbo].[tblExchange] ON 
INSERT [dbo].[tblExchange] ([id], [rate]) VALUES (1, CAST(1.00 AS Decimal(18, 2)))
SET IDENTITY_INSERT [dbo].[tblExchange] OFF
GO

-- %% [markdown]
-- # [dbo].[tblInv]

-- %%
SET IDENTITY_INSERT [dbo].[tblInv] ON 
INSERT [dbo].[tblInv] ([id], [InvID], [InvDate], [InvTime], [Amount], [discount], [payment], [createdate], [UserID], [waiting]) VALUES (1, N'0001', CAST(N'2023-06-23' AS Date), CAST(N'16:41:00' AS Time), CAST(98.01 AS Decimal(18, 2)), CAST(0.00 AS Decimal(18, 2)), CAST(98.01 AS Decimal(18, 2)), CAST(N'2023-06-23' AS Date), N'0002', N'001')
INSERT [dbo].[tblInv] ([id], [InvID], [InvDate], [InvTime], [Amount], [discount], [payment], [createdate], [UserID], [waiting]) VALUES (2, N'0002', CAST(N'2023-06-23' AS Date), CAST(N'16:44:00' AS Time), CAST(66.00 AS Decimal(18, 2)), CAST(0.00 AS Decimal(18, 2)), CAST(66.00 AS Decimal(18, 2)), CAST(N'2023-06-23' AS Date), N'0002', N'002')
INSERT [dbo].[tblInv] ([id], [InvID], [InvDate], [InvTime], [Amount], [discount], [payment], [createdate], [UserID], [waiting]) VALUES (1002, N'0003', CAST(N'2023-06-24' AS Date), CAST(N'12:14:00' AS Time), CAST(132.00 AS Decimal(18, 2)), CAST(0.00 AS Decimal(18, 2)), CAST(132.00 AS Decimal(18, 2)), CAST(N'2023-06-24' AS Date), N'0002', N'003')
SET IDENTITY_INSERT [dbo].[tblInv] OFF
GO

-- %% [markdown]
-- # [dbo].[tblInv_Detail]

-- %%
INSERT [dbo].[tblInv_Detail] ([InvID], [ProID], [ProName], [size], [Qty], [Price], [discount], [Total]) VALUES (N'0001', N'0002', N'BB', N'L', 2, CAST(33.00 AS Decimal(18, 2)), CAST(1.00 AS Decimal(18, 2)), CAST(65.34 AS Decimal(18, 2)))
INSERT [dbo].[tblInv_Detail] ([InvID], [ProID], [ProName], [size], [Qty], [Price], [discount], [Total]) VALUES (N'0001', N'0002', N'BB', N'M', 1, CAST(33.00 AS Decimal(18, 2)), CAST(1.00 AS Decimal(18, 2)), CAST(32.67 AS Decimal(18, 2)))
INSERT [dbo].[tblInv_Detail] ([InvID], [ProID], [ProName], [size], [Qty], [Price], [discount], [Total]) VALUES (N'0002', N'0001', N'Cofee Milk', N'L', 2, CAST(33.00 AS Decimal(18, 2)), CAST(33.00 AS Decimal(18, 2)), CAST(66.00 AS Decimal(18, 2)))
INSERT [dbo].[tblInv_Detail] ([InvID], [ProID], [ProName], [size], [Qty], [Price], [discount], [Total]) VALUES (N'0003', N'0002', N'BB', N'M', 4, CAST(33.00 AS Decimal(18, 2)), CAST(1.00 AS Decimal(18, 2)), CAST(132.00 AS Decimal(18, 2)))
GO

-- %% [markdown]
-- # [dbo].[tblProduct]

-- %%
INSERT [dbo].[tblProduct] ([ProID], [ProName], [Price], [Photo], [CatID], [note], [createddate], [createby]) VALUES (N'0001', N'Cofee Milk', 0, ..., N'0002', N'home', CAST(N'2023-06-23' AS Date), N'1')
INSERT [dbo].[tblProduct] ([ProID], [ProName], [Price], [Photo], [CatID], [note], [createddate], [createby]) VALUES (N'0002', N'BB', 0, ..., N'0001', N'BBB', CAST(N'2023-06-23' AS Date), N'1')
INSERT [dbo].[tblProduct] ([ProID], [ProName], [Price], [Photo], [CatID], [note], [createddate], [createby]) VALUES (N'0003', N'P9', 0, ..., N'0003', N'P9', CAST(N'2023-06-23' AS Date), N'1')
GO

-- %% [markdown]
-- # [dbo].[tblProductDetail]

-- %%
INSERT [dbo].[tblProductDetail] ([proid], [type], [price], [discount], [islocked], [total]) VALUES (N'0001', N'L', CAST(33.00 AS Decimal(18, 2)), CAST(33.00 AS Decimal(18, 2)), 0, CAST(22.11 AS Decimal(18, 2)))
INSERT [dbo].[tblProductDetail] ([proid], [type], [price], [discount], [islocked], [total]) VALUES (N'0001', N'M', CAST(23.00 AS Decimal(18, 2)), CAST(34.00 AS Decimal(18, 2)), 0, CAST(15.18 AS Decimal(18, 2)))
INSERT [dbo].[tblProductDetail] ([proid], [type], [price], [discount], [islocked], [total]) VALUES (N'0001', N'S', CAST(33.00 AS Decimal(18, 2)), CAST(3.00 AS Decimal(18, 2)), 0, CAST(32.01 AS Decimal(18, 2)))
INSERT [dbo].[tblProductDetail] ([proid], [type], [price], [discount], [islocked], [total]) VALUES (N'0002', N'L', CAST(33.00 AS Decimal(18, 2)), CAST(1.00 AS Decimal(18, 2)), 0, CAST(32.67 AS Decimal(18, 2)))
INSERT [dbo].[tblProductDetail] ([proid], [type], [price], [discount], [islocked], [total]) VALUES (N'0002', N'M', CAST(33.00 AS Decimal(18, 2)), CAST(1.00 AS Decimal(18, 2)), 0, CAST(32.67 AS Decimal(18, 2)))
INSERT [dbo].[tblProductDetail] ([proid], [type], [price], [discount], [islocked], [total]) VALUES (N'0003', N'L', CAST(4.00 AS Decimal(18, 2)), CAST(1.00 AS Decimal(18, 2)), 0, CAST(3.96 AS Decimal(18, 2)))
INSERT [dbo].[tblProductDetail] ([proid], [type], [price], [discount], [islocked], [total]) VALUES (N'0003', N'M', CAST(12.00 AS Decimal(18, 2)), CAST(1.00 AS Decimal(18, 2)), 0, CAST(11.88 AS Decimal(18, 2)))
INSERT [dbo].[tblProductDetail] ([proid], [type], [price], [discount], [islocked], [total]) VALUES (N'0003', N'S', CAST(33.00 AS Decimal(18, 2)), CAST(33.00 AS Decimal(18, 2)), 0, CAST(22.11 AS Decimal(18, 2)))
INSERT [dbo].[tblProductDetail] ([proid], [type], [price], [discount], [islocked], [total]) VALUES (N'0002', N'S', CAST(33.00 AS Decimal(18, 2)), CAST(1.00 AS Decimal(18, 2)), 0, CAST(32.67 AS Decimal(18, 2)))
GO

-- %% [markdown]
-- # [dbo].[tblUser]

-- %%
INSERT [dbo].[tblUser] ([UserID], [Name], [UserName], [Password], [Phone], [Photo], [position], [Status]) VALUES (N'1', N'vanchhai', N'vanchhai', N'123456', N'4434', N'334', N'1', N'1')
INSERT [dbo].[tblUser] ([UserID], [Name], [UserName], [Password], [Phone], [Photo], [position], [Status]) VALUES (N'0002', N'chhai', N'chhai', N'123456', NULL, NULL, N'0', N'1')
GO

-- %% [markdown]
-- # [dbo].[tbprint]

-- %%
SET IDENTITY_INSERT [dbo].[tbprint] ON 
INSERT [dbo].[tbprint] ([id], [num], [createdate], [createby]) VALUES (1, N'1', CAST(N'2023-06-23' AS Date), N'vacnnhai')
SET IDENTITY_INSERT [dbo].[tbprint] OFF
GO

-- %% [markdown]
-- # [dbo].[tbwifi]

-- %%
SET IDENTITY_INSERT [dbo].[tbwifi] ON 
INSERT [dbo].[tbwifi] ([id], [pass], [createdate], [createby]) VALUES (1, N'1111', CAST(N'2029-06-23' AS Date), N'vanchahi')
SET IDENTITY_INSERT [dbo].[tbwifi] OFF
GO

-- %% [markdown]
-- # [dbo].[insert_Inv]

-- %%
/****** Object:  StoredProcedure [dbo].[insert_Inv]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[insert_Inv](
	@UserID nvarchar(50),
	@InvDate DATE,
	@invTime TIME,
	@Amount FLOAT,
	@discount FLOAT,
	@payment FLOAT,
	@id VARCHAR(100) OUTPUT
) as
BEGIN

DECLARE @wait VARCHAR(50)
DECLARE @num VARCHAR(50)

--SELECT @num=CASE WHEN (SELECT ISNULL(MAX(waiting),0)+1 FROM dbo.tblInv)=99 THEN 1 ELSE (SELECT ISNULL(MAX(waiting),0)+1 FROM dbo.tblInv) END;
SELECT @wait=dbo.fn_getDigitID((CASE WHEN (SELECT ISNULL(MAX(waiting),0)+1 FROM dbo.tblInv)=99 THEN 0 ELSE (SELECT ISNULL(MAX(waiting),0)+1 FROM dbo.tblInv) END),3);
SELECT @id=dbo.fn_getDigitID((SELECT ISNULL(MAX(InvID),0)+1 FROM dbo.tblInv),4);

	insert into tblInv(InvID,UserID,InvDate,Amount,discount,payment,createdate,InvTime,waiting) values(@id,@UserID,@InvDate,@Amount,@discount,@payment,GETDATE(),@invTime,@wait)
END

GO

-- %% [markdown]
-- # [dbo].[mostProduct]

-- %%
/****** Object:  StoredProcedure [dbo].[mostProduct]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[mostProduct]
@dtFrom date,
@dtTo date
as
begin
	
		select top 5  ProName,ProID,sum(Qty) as tal from tblInv_Detail inner join tblInv on tblInv_Detail.InvID=tblInv.InvID
		 where tblInv.InvDate between @dtFrom and @dtTo  group by ProID,ProName order by tal desc

end

GO

-- %% [markdown]
-- # [dbo].[mostProductNoCon]

-- %%
/****** Object:  StoredProcedure [dbo].[mostProductNoCon]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[mostProductNoCon]

as 

begin
	select top 5 ProName,ProID,sum(Qty) as tal from tblInv_Detail group by ProID,ProName order by tal desc

end

GO

-- %% [markdown]
-- # [dbo].[sp_cate]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_cate]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_cate]

@name NVARCHAR(255),
@dec NVARCHAR(max),
@createby NVARCHAR(255)
AS
BEGIN
	DECLARE @cateid VARCHAR(255)
	select @cateid=dbo.fn_getDigitID(isnull(max(CatID),0)+1 ,4) from dbo.tblCat
	INSERT INTO dbo.tblCat
	        ( CatID, CatName, description,createdate,createby )
	VALUES  (@cateid, -- CatID - nvarchar(255)
	          @name, -- CatName - nvarchar(255)
	          @dec,  -- Image - nvarchar(255)
			  GETDATE(),
			  @createby
	          )
END


GO

-- %% [markdown]
-- # [dbo].[sp_cate_e]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_cate_e]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[sp_cate_e]

@name NVARCHAR(255),
@dec NVARCHAR(max),
@createby NVARCHAR(255),
@id VARCHAR(50)
AS
BEGIN
	UPDATE dbo.tblCat SET CatName=@name,description=@dec,updateby=@createby,updatedate=GETDATE() WHERE CatID=@id          
END

GO

-- %% [markdown]
-- # [dbo].[sp_expens]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_expens]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_expens](
@ex_date DATE ,
@amount DECIMAL(20,2),
@descriptions NVARCHAR(max),
@createdby NVARCHAR(10) 
)
AS

BEGIN
    INSERT INTO dbo.tbexpens
            ( ex_date ,
              amount ,
              descriptions ,
              createdby ,
              createdate
            )
    VALUES  (   @ex_date ,
				@amount,
				@descriptions ,
				@createdby, 
              GETDATE()
            )
END

GO

-- %% [markdown]
-- # [dbo].[sp_insert_inv_detail]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_insert_inv_detail]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[sp_insert_inv_detail](
			  @InvID VARCHAR(100),
              @ProID VARCHAR(100) ,
              @ProName NVARCHAR(100),
              @Qty INT,
              @Price DECIMAL(18,2),
              @Total DECIMAL(18,2),
			  @size VARCHAR(10),
			  @decount DECIMAL(18,2)

)
AS
BEGIN
    INSERT INTO dbo.tblInv_Detail
            ( InvID ,
              ProID ,
              ProName ,
              Qty ,
              Price ,
              Total,
			  size,
			  discount
            )
    VALUES  ( @InvID ,
              @ProID  ,
              @ProName ,
              @Qty ,
              @Price ,
              @Total ,
			  @size ,
			  @decount 
            )
END

GO

-- %% [markdown]
-- # [dbo].[sp_invoice]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_invoice]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_invoice](
	@invID VARCHAR(100)
)
AS 
BEGIN
    SELECT 
		i.InvID,
		i.InvDate,
		i.InvTime,
		i.Amount,
		i.discount,
		i.payment,
		d.ProName,
		d.discount AS dis,
		d.size,
		d.Qty,
		d.Price,
		d.Total,
		i.UserID,
		i.waiting
	 FROM dbo.tblInv i INNER JOIN
	dbo.tblInv_Detail d ON
    i.InvID=d.InvID WHERE i.InvID=@invID
END

GO

-- %% [markdown]
-- # [dbo].[sp_product_detail_i]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_product_detail_i]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROC [dbo].[sp_product_detail_i]
(
	@pid VARCHAR(50),
	@type VARCHAR(5),
	@price DECIMAL(20,2),
	@discount DECIMAL(18,2)

)
AS

BEGIN
    DECLARE @total DECIMAL(18,2)
	SET @total=@price-(@price*@discount/100)
	INSERT INTO dbo.tblProductDetail
	        ( proid, type, price, islocked,discount,total)
	VALUES  ( @pid,
			  @type,
			  @price,
	          0  -- islocked - tinyint
			  ,@discount,
			  @total
	          )
END



GO

-- %% [markdown]
-- # [dbo].[sp_product_e]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_product_e]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_product_e]
(
	@proname NVARCHAR(100),
	@photo VARBINARY(MAX),
	@cateid NVARCHAR(255),
	@note NVARCHAR(MAX),
	@createdby NVARCHAR(100),
	@id VARCHAR(50)
)
	AS
    
BEGIN
   update  dbo.tblProduct SET ProName=@proname, Photo=@photo, CatID=@cateid ,note=@note,createby=@createdby WHERE ProID=@id
   DELETE FROM dbo.tblProductDetail WHERE proid=@id
              
END

GO

-- %% [markdown]
-- # [dbo].[sp_product_i]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_product_i]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_product_i]
(
	@proname NVARCHAR(100),
	@photo VARBINARY(MAX),
	@cateid NVARCHAR(255),
	@note NVARCHAR(MAX),
	@createdby NVARCHAR(100),
	@id VARCHAR(50) output
)
	AS
    
BEGIN
SELECT @id=dbo.fn_getDigitID((SELECT ISNULL(MAX(ProID),0)+1 FROM dbo.tblProduct),4);
   INSERT INTO dbo.tblProduct
           ( ProID,ProName, Price, Photo, CatID ,note,createby,createddate)
   VALUES  (@id, @proname, 0, @photo, @cateid,@note,@createdby,GETDATE())
   
              
END

GO

-- %% [markdown]
-- # [dbo].[sp_rpt_change_time]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_rpt_change_time]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROC [dbo].[sp_rpt_change_time]
    (
      @datefrom DATE ,
      @dateto DATE ,
      @userID NVARCHAR(100)
    )
AS
    BEGIN
        SELECT 
	 DISTINCT   d.ProID ,
                d.ProName ,
                d.Price ,
                d.size ,
                ( SELECT    SUM(l.Qty)
                  FROM      dbo.tblInv_Detail l INNER JOIN dbo.tblInv v ON l.InvID=v.InvID
                  WHERE     l.ProID = d.ProID
                            AND l.size = d.size AND v.UserID=i.UserID and v.InvDate BETWEEN @datefrom AND @dateto
                           
                ) AS qty ,
                ( SELECT    SUM(l.Qty)
                  FROM      dbo.tblInv_Detail l INNER JOIN dbo.tblInv v ON l.InvID=v.InvID
                  WHERE     l.ProID = d.ProID
                            AND l.size = d.size AND v.UserID=i.UserID and v.InvDate BETWEEN @datefrom AND @dateto
                           
                ) * d.Price AS Total ,
                u.Name ,
                u.UserID
        FROM    dbo.tblInv i
                INNER JOIN dbo.tblInv_Detail d ON i.InvID = d.InvID
                INNER JOIN dbo.tblUser u ON i.UserID = u.UserID
        WHERE   i.InvDate BETWEEN @datefrom AND @dateto
                AND i.UserID = @userID;
    END;
GO

-- %% [markdown]
-- # [dbo].[sp_rpt_checkout]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_rpt_checkout]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_rpt_checkout](
@datefrom DATE,
@dateto DATE
)

AS
BEGIN
    SELECT payment AS amount,N'លក់' AS Note,'Income' AS status FROM dbo.tblInv WHERE InvDate BETWEEN @datefrom AND @dateto
	UNION ALL
    SELECT amount AS amount,descriptions AS Note,'Expens' AS status FROM dbo.tbexpens WHERE ex_date BETWEEN @datefrom AND @dateto
END

GO

-- %% [markdown]
-- # [dbo].[sp_rpt_daily_checkout]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_rpt_daily_checkout]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_rpt_daily_checkout]
    (
      @datefrom DATE ,
      @dateto DATE
    )
AS
    BEGIN
         SELECT 
	 DISTINCT   d.ProID ,
                d.ProName ,
                d.Price ,
                d.size ,
                ( SELECT    SUM(l.Qty)
                  FROM      dbo.tblInv_Detail l INNER JOIN dbo.tblInv v ON l.InvID=v.InvID
                  WHERE     l.ProID = d.ProID
                            AND l.size = d.size AND v.UserID=i.UserID
                           
                ) AS qty ,
                ( SELECT    SUM(l.Qty)
                  FROM      dbo.tblInv_Detail l INNER JOIN dbo.tblInv v ON l.InvID=v.InvID
                  WHERE     l.ProID = d.ProID
                            AND l.size = d.size AND v.UserID=i.UserID
                           
                ) * d.Price AS Total ,
                u.Name ,
                u.UserID
        FROM    dbo.tblInv i
                INNER JOIN dbo.tblInv_Detail d ON i.InvID = d.InvID
                INNER JOIN dbo.tblUser u ON i.UserID = u.UserID
        WHERE   i.InvDate BETWEEN @datefrom AND @dateto
    END;

--WHERE i.InvDate BETWEEN @datefrom AND @dateto


GO

-- %% [markdown]
-- # [dbo].[sp_rpt_expense]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_rpt_expense]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 CREATE PROC [dbo].[sp_rpt_expense]
(
@datefrom DATE,
@dateto DATE
)
AS BEGIN
       
	   SELECT x.id ,
              x.ex_date ,
              x.amount ,
              x.descriptions ,
              x.createdby ,
              u.Name
               FROM
       dbo.tbexpens x INNER JOIN dbo.tblUser u
	   ON x.createdby=u.UserID
	    WHERE ex_date BETWEEN @datefrom AND @dateto 
   END
GO

-- %% [markdown]
-- # [dbo].[sp_rpt_expense_user]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_rpt_expense_user]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_rpt_expense_user]
(
@datefrom DATE,
@dateto DATE,
@user VARCHAR(100)
)
AS BEGIN
       
	   SELECT x.id ,
              x.ex_date ,
              x.amount ,
              x.descriptions ,
              x.createdby ,
              u.Name
               FROM
       dbo.tbexpens x INNER JOIN dbo.tblUser u
	   ON x.createdby=u.UserID
	    WHERE ex_date BETWEEN @datefrom AND @dateto AND createdby=@user
   END

GO

-- %% [markdown]
-- # [dbo].[sp_rpt_product]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_rpt_product]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_rpt_product] (
	@datefrom DATE,
	@dateto DATE
)
AS

BEGIN
    
	SELECT p.ProID,p.ProName,pd.type,pd.price,u.Name,p.createddate,
	ISNULL((SELECT SUM(d.qty) from dbo.tblInv i 
	INNER JOIN dbo.tblInv_Detail d ON i.InvID=d.InvID AND d.ProID=p.ProID AND i.InvDate BETWEEN @datefrom AND @dateto AND pd.type=d.size ),0) AS qty
	FROM dbo.tblProduct p INNER JOIN dbo.tblUser u ON p.createby=u.UserID INNER JOIN dbo.tblProductDetail pd
	ON p.ProID=pd.proid ORDER BY qty DESC
END

GO

-- %% [markdown]
-- # [dbo].[sp_rpt_sell]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_rpt_sell]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_rpt_sell](
@date DATE
)
AS
BEGIN
    
	SELECT InvID ,
           InvDate ,
           InvTime ,
           Amount ,
           discount ,
           payment ,
           createdate ,
           UserID FROM dbo.tblInv WHERE InvDate=@date
END

GO

-- %% [markdown]
-- # [dbo].[sp_runSQL]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_runSQL]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[sp_runSQL]
	@sql nvarchar(max)
	as exec(@sql)

GO

-- %% [markdown]
-- # [dbo].[sp_user]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_user]    Script Date: 7/6/2023 10:07:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[sp_user](
@SureName NVARCHAR(100),
@UserName NVARCHAR(100),
@Password NVARCHAR(100),
@ProfileID NVARCHAR(20)
)
AS

BEGIN
DECLARE @user NVARCHAR(100)
SET @user=dbo.fn_getDigitID((SELECT ISNULL(MAX(UserID),0)+1 FROM dbo.tblUser),4);

    INSERT INTO dbo.tblUser
            ( UserID ,
              Name ,
              UserName ,
              Password ,
              position ,
              Status
            )
    VALUES  ( @user, -- UserID - nvarchar(50)
              @SureName  , -- Name - nvarchar(255)
              @UserName  , -- UserName - nvarchar(255)
              @Password  , -- Password - nvarchar(255)
              @ProfileID , -- position - nvarchar(50)
              N'1'  -- Status - nvarchar(50)
            )
    
END

GO

-- %% [markdown]
-- # [poscoffe]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [poscoffe] SET  READ_WRITE 
GO
